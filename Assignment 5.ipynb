# %% [markdown]
# ### 2011136103 장현승

# %% [markdown]
# - [1번 문제] 클래스와 모듈의 공통점과 차이점에 대해 설명하시오.

# %% [markdown]
#   - 공통점 : 비슷하거나 관련된 일을 하는 함수나 상수값들을 모아서 저장하고 추후에 재사용하기 편리하다.
#   - 차이점 : 클래스는 인스턴스를 가질 수 있으나, 모듈은 그렇지 못한다.

# %% [markdown]
# - [2번 문제] 다형성에 대해 설명하고 다형성을 보여주는 자신만의 파이썬 코드 예제를 제시하시오.

# %%
class Animal:
    def whoami(self):
        print '...'
        
class Dog(Animal):
    def whoami(self):
        print 'Dog'
        
class Duck(Animal):
    def whoami(self):
        print 'Duck'
        
class Fish(Animal):
    def whoami(self):
        print 'Fish'
        
class hyunseoung(Animal):
    def whoami(self):
        print '현승'

for each in (Dog(), Duck(), Fish(), hyunseoung()):
    each.whoami()
# Out:
# Dog
# Duck
# Fish
# 현승

# %% [markdown]
# - [3번 문제] 다음 각 요구사항 모두를 만족시키는 Counter 클래스를 코딩하시오 (정답을 각 요구사항별로 입력할 필요 없이 3번 문제에 대해 1개의 클래스 정의 코드를 제시하면 된다.)
#  - ◾ 요구사항 1. 생성자에 count 값과 step 값을 인자로 받을 수 있다.
#  - count: Counter 인스턴스가 지니는 초기 정수 값
#  - step: Counter 인스턴스의 count가 증가되는 증분 (defalt 값: 1)
#
#
# >  c = Counter(10) <br/>
# >  d = Counter(10, 2) <br/>
#
#
# - ◾ 요구사항 2. 다음과 같이 Counter의 인스턴스를 출력을 해주는 __str__() 메소드를 구현하시오.
#
#
# > print c <br/>
# > [Count (step: 1)] 10 <br/>
# > print d <br/>
# > [Count (step: 2)] 10 <br/>
#
#
# - ◾ 요구사항 3. 다음과 같이 step에 주어진 증분만큼 count를 증가시키는 incr() 메소드를 구현하시오.
#
#
# > c.incr() <br/>
# > d.incr() <br/>
# > print c <br/>
# > [Count (step: 1)] 11 <br/>
# > print d <br/>
# > [Count (step: 2)] 12 <br/>
#
#
# - ◾ 요구사항 4. __call__() 메소드를 추가하여 인스턴스 객체를 직접 호출할 수 있도록 하시오. 인스턴스 객체를 직접 호출했을 때의 동작방식은 incr() 메소드를 호출하였을 때와 동일하다.
#
#
# > c() <br/>
# > d() <br/>
# > print c <br/>
# > [Count (step: 1)] 12 <br/>
# > print d <br/>
# > [Count (step: 2)] 14 <br/>
#
#
# - ◾ 요구사항 5. 다음과 같은 두 개의 산술 연산 (+, -)이 수행될 수 있도록 관련 메소드를 추가하시오.
#
#
# > c = c + 5 <br/>
# > d = d - 5 <br/>
# > print c <br/>
# > [Count (step: 1)] 17 <br/>
# > print d <br/>
# > [Count (step: 2)] 9 <br/>
#
#
# - ◾ 요구사항 6. 다음과 같은 관계연산 (+, -)이 수행될 수 있도록 __cmp__() 메소드를 추가하시오.
#
#
# > print c > 10 <br/>
# > True <br/>
# > print d > 10 <br/>
# > False <br/>\n
# > print c < 10 <br/>
# > False <br/>
# > print d < 10 <br/>
# > True <br/>
# > print c == 17 <br/>
# > True <br/>
# > print d != 9 <br/>
# > False <br/>

# %%
class Counter :
    
    def __init__(self, count, step=1) :
        self.count = count
        self.step = step
        
    def __str__(self):
        result = "[Count (step:"
        result +=  (str)(self.step)
        result += ")] "
        result += (str)(self.count)      
        return result    
           
    def incr(self):
        self.count += self.step
     
    def __call__(self):
        self.count += self.step
        
    def __add__(self, num):
        return Counter(self.count + num, self.step)
    
    def __sub__(self, num):
        return Counter(self.count - num, self.step)
        
    def __cmp__(self, num):
            return self.count - num
    
        
# 1
c = Counter(10)
d = Counter(10,2)
# 2
print 
print c
print d
# 3
print 
c.incr()
d.incr()
print c
print d
# 4
print 
c()
d()
print c
print d
# 5
print 
c = c+5
d = d-5
print c
print d
# 6
print 
print c > 10
print d > 10
print c < 10
print d < 10
print c == 17
print d != 9
# Out:
# [Count (step:1)] 10
# [Count (step:2)] 10
#
# [Count (step:1)] 11
# [Count (step:2)] 12
#
# [Count (step:1)] 12
# [Count (step:2)] 14
#
# [Count (step:1)] 17
# [Count (step:2)] 9
#
# True
# False
# False
# True
# True
# False

# %% [markdown]
# C와 자바의 생성자, 멤버함수를 정의하는 것과 비슷한 것 같다.

# %% [markdown]
# - [4번 문제] 다음은 내장 자료형 list를 서브클래싱하여 만든 MySet 클래스 정의 내용이다. 다음 클래스 정의에서 __init__(), __str()__(), elimicate_duplicate()의 세 개의 메소드 코드 내용을 자신이 다른 사람에게 가르친다고 생각하며 설명해보시오.
#  - MySet은 집합(Set) 자료형을 정의하려는 의도하에 만들어진 클래스이다.

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:]= [] 
        for e in s:
            l.append(e)

    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print s
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print t
# Out:
# MySet: {1 ,2 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,8 ,8 ,8 ,8 ,9}

# %% [markdown]
# Myset 클래스는 list를 상속 받았고, init 생성자에서는 정적함수를 호출하고 있는데 이 함수는 배열에서 같은 값이 중복되면 지우는 함수입니다.
# 그리고 str은 객체의 출력을 문자열로 할 수 있도록 만듭니다.

# %% [markdown]
# - [5번 문제] 4번 문제에 정의된 MySet 클래스에 메소드를 추가하여 다음 각 요구사항 모두를 만족시키는 코딩을 제시하시오 (정답을 각 요구사항별로 입력할 필요 없이 5번 문제에 대해 1개의 MySet 클래스 정의 코드를 제시하면 된다.)
#
#  - ◾ 요구사항 1. | 연산으로 두 집합의 합집합을 반환한다.
#
# > s = s | t <br/>
# > print s <br/>
#  MySet: {1 ,2 ,3 ,4 ,5 ,6 ,7 ,8 ,9} <br/>
#
#
#  - ◾ 요구사항 2. & 연산으로 두 집합의 교집합을 반환한다.
#
# > s = MySet([1, 2, 3]) <br/>
# > t = MySet([3, 4, 5]) <br/>
# > s = s & t <br/>
# > print s <br/>
#  MySet: {3} <br/>
#
#
#  - ◾ 요구사항 3. - 연산으로 두 집합의 차집합을 반환한다.
#
# > s = MySet([1, 2, 3]) <br/>
# > t = MySet([3, 4, 5]) <br/>
# > s = s - t <br/>
# > print s <br/>
#  MySet: {1, 2} <br/>

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result
        
    def __or__(self, other):
        for e in other :
            if e not in self:
                self.append(e)
        return self
        
    def __and__(self, other):
        tmp = []
        for e in self:
            if e not in other:
                tmp.append(e)
        for e in tmp:
            self.remove(e)
        return self
        
    def __sub__(self, other):
        tmp = []
        for e in self:
            if e in other:
                tmp.append(e)
        for e in tmp:
            self.remove(e)
        return self
        
    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)

    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print s
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print t  
    
    #1
    s = s | t
    print s
    
    #2
    s = MySet([1,2,3])
    t = MySet([3,4,5])
    s = s & t
    print s
    
    #3
    s = MySet([1,2,3])
    t = MySet([3,4,5])
    s = s - t
    print s
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}
# MySet: {1 ,2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}
# MySet: {3}
# MySet: {1 ,2}

# %% [markdown]
# 합집합 교집합 차집합을 각각 연산자 오버로딩을 사용해서 재정의 했다.

# %% [markdown]
# - [6번 문제] 5번 문제에서 정의한 MySet 클래스에 대해 다음 예제를 수행하면 오류없이 올바르게 동작하는 것을 확인할 수 있다. 다음 예제 내에 있는 len(), bool() 내장함수와 in 키워드 사용 예제가 별다른 메소드 정의를 하지 않았는 데도 올바르게 수행되는 이유를 설명하시오.
#
#
# > s = MySet([1, 2, 3, 4, 5, 6]) <br/>
# > print len(s) <br/>
#  6 <br/>
# > print bool(s) <br/>
#  True <br/>
# > print 2 in s <br/>
#  True <br/>

# %% [markdown]
# Myset은 list클래스를 상속 받았기 때문에 list클래스에 정의된 메소드를 사용할 수 있다.

# %% [markdown]
# - [7번 문제] 이전 Assignment 3 (Assignment 4가 아님)의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하여 각 단어들에 대해 출현빈도를 사전형태({'world': 2, 'hello': 1, 'python': 1})로 저장하여 출력하는 것이었다. 이번에는 Assignment 3과 Assignment 4를 확장/변형하여 다음과 같은 조건을 만족하도록 구현하시오.
#  - 1) 새로운 클래스 WebWordsFrequency를 정의하시오.
#  - 2) 생성자에 URL을 0개에서 임의의 개수를 넣을 수 있도록 생성자 인수를 가변인수로 정의하여 각각의 URL을 리스트 자료형에 유지하시오.
#
# >w1 = WebWordsFrequency('http://www.daum.net', 'http://www.naver.com', 'http://www.google.co.kr') <br/>
# > w2 = WebWordsFrequency('http://www.daum.net', 'http://www.naver.com') <br/>
# > w3 = WebWordsFrequency() <br/>
#
#
#  - 3) addUrl() 메소드를 구현하여 인스턴스를 생성한 이후에도 URL을 추가할 수 있도록 한다.
#   - 반드시 1개의 URL을 추가하도록 구현 (즉, 동시에 여러 개의 URL을 추가하는 것은 배제)
#
#
# > w1.addUrl('http://cse.koreatech.ac.kr')<br/>
# > w3.addUrl('http://www.koreatech.ac.kr')<br/>
#
#
#  - 4) removeUrl() 메소드를 구현하여 URL을 삭제할 수 있도록 한다.
#   - 반드시 1개의 URL을 삭제하도록 구현 (즉, 동시에 여러 개의 URL을 삭제하는 것은 배제)
#
#
# > w1.removeUrl('http://www.daum.net')<br/>
# > w2.removeUrl('http://www.naver.com')<br/>
#
#
#  - 5) listUrls() 메소드를 구현하여 현재 등록된 모든 URL을 출력하는 기능을 추가
#
# > w1.listUrls()<br/>
# > http://www.naver.com <br/>
# > http://www.google.co.kr <br/>
# > http://cse/koreatech.ac.kr <br/>
#
#
#  - 6) getWordsFrequency() 메소드를 구현하여 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현 빈도 사전을 반환하시오.
#   - 만약 등록된 URL이 없다면 공백 사전을 반환
#
#
# > w1.getWordsFrequency() <br/>
#  {'다음': 8, '안녕': 12, 'world': 2, '우리': 11, 'hello': 1, 'python': 1} <br/>
#
#  - 7) getMaxFreqencyWords() 메소드를 구현하여 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현 빈도 사전에서 가장 많이 출현한 단어 리스트를 반환하시오.
#   -최다 출현 단어의 빈도수가 동일한 경우 모두 출력해주어야 함
#   -만약 등록된 URL이 없다면 None을 반환
#
#
# >w1.getMaxFreqencyWords() <br/>
# 우리 <br/>
# >w2.getMaxFreqencyWords() <br/>
# 다음에 <br/>
#  안녕 <br/>
#
#  - 8) Assignment 4에서 요구했던 파일로 저장하는 코드는 모두 삭제하시오.

# %%
import urllib
import string

def getWordsFrequency(url):
        source = urllib.urlopen(url).read()
        i = 0
        len_source = len(source)
        while (i < len_source):
            found = False
            if (found != True and source[i] == "<" and source[i+1 : i+7].lower() == "script"):
                found = True;
                j = i + 7;
                while (True):
                    if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+8].lower() == "script"):
                        #print "found - script"
                        source = source[:i] + ' ' + source[j+9:]
                        break
                    j = j + 1
                    if (j > len_source):
                        break
                len_source = len(source)
            i = i + 1

        i = 0
        len_source = len(source)
        while (i < len_source):
            found = False
            if (found != True and source[i] == "<" and source[i+1 : i+6].lower() == "style"):
                found = True;
                j = i + 6;
                while (True):
                    if (source[j] == "<" and source[j+1] == "/" and source[j+2 : j+7].lower() == "style"):
                        source = source[:i] + ' ' + source[j+8:]
                        break
                    j = j + 1
                    if (j > len_source):
                        break
                len_source = len(source)
            i = i + 1

        i = 0
        len_source = len(source)
        while (i < len_source):
            found = False
            if (found != True and source[i] == "<"):
                found = True;
                j = i + 1;
                while (True):
                    if (source[j] == ">"):
                        source = source[:i] + ' ' + source[j+1:]
                        break
                    j = j + 1
                    if (j > len_source):
                        break
                len_source = len(source)
            i = i + 1

    
        i = 0
        len_source = len(source)
        while(i < len_source):
            for j in string.punctuation :
                if (j==source[i]):   
                    source = source[:i] + ' ' + source[i+1:]
                    break
            i = i + 1


        words = source.split()
        d = {}
        for word in words:
            if(word in d):
                d[word] = d[word] +1
            else :
                d[word] = 1   
                
        return d

class WebWordsFrequency:
    def __init__(self, *arg):
        self.urlList = []
        for url in arg:
            self.urlList.append(url)        
    def addUrl(self, url):
        self.urlList.append(url)
        
    def removeUrl(self, url):
        self.urlList.remove(url)
        
    def listUrls(self):
        for url in self.urlList:
            print url
    def getWordsFrequency(self):
        dic = {}
        tmp = {}
        for url in self.urlList:
            tmp = getWordsFrequency(url)
            for word in tmp:
                if(word in dic):
                    dic[word] = dic[word] +1
                else :
                    dic[word] = 1  
        return dic
    
    def getMaxFreqencyWords(self):
        dic = self.getWordsFrequency()
        words = []
        maxKey = 0
        for i in dic.items():
            if i[1] > maxKey:
                maxKey = i[1];
                
        for i in dic.items():
            if i[1] == maxKey:
                words.append(i[0])
        return words
                
        
w1 = WebWordsFrequency('http://www.daum.net', 'http://www.naver.com', 'http://www.google.co.kr')
w2 = WebWordsFrequency('http://www.daum.net', 'http://www.naver.com')    
w3 = WebWordsFrequency() 

w1.addUrl('http://cse.koreatech.ac.kr')
w2.addUrl('http://cse.koreatech.ac.kr')
w3.addUrl('http://www.koreatech.ac.kr')

w1.removeUrl('http://www.daum.net')
w2.removeUrl('http://www.naver.com')

print "listUrls()"
w1.listUrls()
print

print "getWordsFrequency()"
print '{',
for i in w1.getWordsFrequency().items():
    print "'%s':%d," % i,
print '}'
print

print "getMaxFreqencyWords()"
for i in w1.getMaxFreqencyWords():
    print i

print
for i in w2.getMaxFreqencyWords():
    print i
# Out:
# listUrls()
# http://www.naver.com
# http://www.google.co.kr
# http://cse.koreatech.ac.kr
#
# getWordsFrequency()
# {
# '찬바람이':1, '���α׷�':1, '한글캠페인':1, '위하여':1, '나눔글꼴이':1, '나눔':1, '라이브':1, '내엄마':1, '����':1, '����':1, '나눔글꼴을':1, '선호주제설정':1, '������':1, '볼':1, '클릭하세요':1, '취업게시판':1, '0':1, 'IT기술봉사':1, '제대로':1, '켜지네':1, '�α���':1, '프로모션':1, '임의로':1, '시스템글꼴':1, '����ϴ�':1, '증시':1, '기존':1, '홈':1, '를':1, '고객센터':1, '주제형캐스트':1, '때는':1, '플랫폼':1, '제공되지':1, '모집':1, '자주':1, '기사보기':1, '앱':1, '찾아오시는길':1, '통신':2, '네이버뉴스':1, '설치된':1, '바버렛츠':1, '자동차':1, '연구':1, '전문보기':1, '완료되지':1, '국어사전':1, '휘닉스디지탈테크':1, '어학':1, '주요언론사':1, '002AN':1, '002AP':1, '설정된':1, '설치하세요':1, 'new':1, '부동산':1, '한게임':1, '닫기':1, '폰트를':1, '6대학생회':1, '켤':1, '전셋값':1, '그린':1, '����̺�':1, '카테고리':1, '미뤘나':1, '사진게시판':1, '문제':1, '확인':1, '30':1, '취업조사2013':1, '1000원':1, '이용을':1, '취업조사2014':1, '않고':1, '권혁주':1, '검색어저장':1, '직접':1, '경우에':1, '��ް˻�':1, '통합검색':1, '타임스퀘어':1, 'txt':1, '홈페이지':1, 'unit':1, '앱을':1, '고속도로교통상':1, '정책':1, '뉴스':1, '캠프':1, '달빛':1, '도전':1, '경진대회':1, '설계1':1, '공학인증안내':1, '라이프':1, '주':1, '할리퀸':1, '개인정보':1, '개인정보취급방침':1, '제6대':1, '승무원들에':1, '인물':1, '검색어를':1, '대학원소개':1, 'none':1, '대해':1, '건강':1, '열기':1, '8위':1, '북스':1, '메뉴':1, '진출':1, '아이디로':1, '엄마와':1, 'Chrome':1, '저장되지':1, '필냉이':1, '나눔글꼴로':1, '�˻�':1, '7위':1, 'CAM':1, '금':1, '시민구단의':1, '금요일':1, 'CAD':1, '나만의':1, '남녀의':1, '글꼴설정':1, '교육과정':1, '6위':1, '뜻':1, '1':1, '짭쪼롬':1, '카페':1, '공룡':1, '내딸':1, '증권':1, 'A':1, '반드시':1, '���':1, '영자지':1, '기록':1, '가능합니다':1, '유정석':1, 'date':1, '않은':1, '활성화로':1, '얼굴에':1, '2호선':1, '네이버를':1, '학회장':1, '포르트무스':1, '켜기':1, '검색어는':1, '해요':1, '생각한대로':1, '추가하시려면':1, '실시간':1, '자세히보기':1, '���ͳ���':1, '연합뉴스':1, '개인':1, '오늘의신문':1, '사과할':1, '보내기':1, '27':1, '체제':1, '방송':1, '박태준':1, '주요뉴스를':1, '블로그':1, '걸린':1, '2014':3, '이벤트':1, '앱스토어':1, '하이라이트':1, '2012':1, '오늘은':1, '지속':1, '너':1, '용어사전':1, 'hellip':1, '시작페이지로':1, '질문형':1, '겨울을':1, '����':1, '박시은':1, '오늘의':1, 'nrefreshx':1, '검색어로':1, '반납':1, '게임':1, '금요':1, '매출':1, '교육목표':1, '신규':1, '청소년유해매체물':1, '강등':1, '본인확인':1, '빠른':1, '전송은':1, 'static':1, '버튼을':1, 'NAVER':1, '사용하고':1, '입력':1, '81':1, '84':1, '최근검색어':1, '방송기술':1, '경제':1, '교수진':1, '학부사진겔러리':1, '내PC':1, '붕어빵':1, '학생회':1, '취소':1, '재설치':1, '�̹���':1, '신입직원':1, '따뜻하게':1, '시장':1, '투표':1, '오브':1, '지워주세요':1, '눈이':1, '240':1, 'W':1, '남자의':1, '끝낸':1, '무료입니다':1, '쇼핑':1, '마주치고':1, '웹문서':1, '유형':1, '��':1, '1회':1, '전문지':1, 'times':1, '묻었어':1, '2015학년도':1, '전문자료':1, '의미':1, '선택':1, '수':1, '현대HCN':1, '구르미':1, '지도':1, '김광현':1, '회복에':1, '예능':1, '�ѱ�':1, 'nhn':1, '않는':1, '보세요':1, '신':1, '공유가':1, '장르소설':1, '장학제도':1, '171':1, '두':1, 'TV캐스트':1, '�ٿ�ε�':1, '美':1, '구독설정':1, '7월30일':1, '공지입니다':1, '다음캐스트':1, '잔두야의':1, '업계':1, '미우나':1, '해제':1, '�ַ��':1, '투데이':1, '저쪽에':1, '회사소개':1, '보호를':1, '로그아웃을':1, '고객님의':1, '김지훈':1, 'x2':1, '목숨이':1, 'copy':2, '최대':1, '석사이상':1, '뮤직':1, '도움말':1, '12':2, '소프트웨어':1, '14':1, '초대합니다':1, '플랫폼의':1, 'PC에서는':1, '미리보기':1, '전자정부':1, '장씨세가':1, '시스템':1, '공지':1, 'VoD':1, 'Gmail':1, '컴퓨터공학부':1, '모든':1, '무료로':1, '디지털':1, '공학부':1, '부안상설시장':1, '오류':1, '사전':1, '가':1, '전':1, '이름의':1, '기업을':1, '제':1, '개':1, '없습니다':1, '일반자료실':1, '갓':1, 'IT융합':1, '자유게시판':1, '만화':1, '왜':1, '메인에서':1, '해피엔딩의':1, '브로셔':1, '01':1, '있습니다':1, '김':1, '최근검색어에서':1, '1위':1, '4위':1, '부학':1, '채용':1, '����':1, '인턴십':1, '오늘':1, 'raquo':1, '블랙프':1, '번호는':1, '오픈캐스트':1, '메인을':1, '컴퓨터시스템응용':1, '3위':1, '웹툰':1, '지역':1, '웹소설':1, '않습니다':1, 'N드라이브':1, '표준프레임워크':1, '����':1, '당신을':1, '사용':1, '연구실소개':1, '신작':1, '현재':1, '모집요강':1, '땐':1, '요일별':1, '다시':1, '검색등록':1, '최종':1, '검색':1, '10':2, '자동완성':1, '압박':1, '강좌':1, '123':1, '영원히':1, '공연에':1, '구독목록':1, '우리':1, '재보궐선거':1, '서울':1, '제2롯데월드':1, '윤이수':1, '뚫었다··':1, '급행노선':1, '국산':1, '강의자료실':1, 'nbsp':3, '315':1, '동문게시판':1, '광고':1, '알림':1, '전체':1, '공지사항':2, '03':1, '9위':1, '07':1, '신문':1, '영어사전':1, '08':1, '09':1, '위한':1, '3':1, '완료':1, '그게':1, '직물설계':1, '4대':1, '24':1, 'C':1, '검색해':1, '����Ͻ�':1, '외모지상주의':1, '이전페이지':1, '주제별캐스트':1, '콘서트':1, '계룡공업고등학교의':1, '����':1, '공용':1, '메일':1, '2위':1, '박용제':1, '다음':1, 'PC에서':1, '선거일까지':1, '���':1, '3사…새':1, '백과사전':1, '선택하여':1, '나눔글꼴':1, '필요합니다':1, '익명게시판':1, 'com':2, '전체언론사':1, '해':1, '다운로드URL ...
#
# getMaxFreqencyWords()
# nbsp
# 2014
#
# 1
# 공지사항
# 7
# 11
# 12
# 14
# KT
# 08
# 4
# 안내

# %% [markdown]
# - [8번 문제] 7번 문제에서 정의한 WebWordsFrequency 클래스를 상속하여 OrderedWebWordsFrequency 클래스를 정의하고 슈퍼클래스에 정의된 getWordsFrequency() 메소드를 오버라이드 하여 단어 출현 빈도를 내림 차순으로 정렬하여 리스트로 출력하시오.
#  - 리스트 내의 각 원소는 단어와 빈도를 쌍으로 지니는 튜플이다.
#
#
# > w4 = OrderedWebWordsFrequency('http://www.daum.net', 'http://www.naver.com', 'http://www.google.co.kr') <br/>
# > w4.getWordsFrequency() <br/>
# [('안녕', 12), ('우리', 11), ('다음', 8), ('world', 2), ('hello', 1), ('python', 1)] <br/>

# %%
class OrderedWebWordsFrequency(WebWordsFrequency):
    def getWordsFrequency(self):
        dic = {}
        tmp = {}
        for url in self.urlList:
            tmp = getWordsFrequency(url)
            for word in tmp:
                if(word in dic):
                    dic[word] = dic[word] +1
                else :
                    dic[word] = 1  
        
        dic = sorted(dic.items(), key=lambda x:x[1], reverse=True)
        
        return dic
        
w4 = OrderedWebWordsFrequency('http://www.daum.net', 'http://www.naver.com', 'http://www.google.co.kr') 
print

print '[',
for i in w4.getWordsFrequency():
    print '(\'%s\', %d),' % i,
print ']'
# Out:
# [
# ('copy', 3), ('com', 3), ('0', 2), ('고객센터', 2), ('자주', 2), ('자동차', 2), ('8위', 2), ('부동산', 2), ('닫기', 2), ('현재', 2), ('책', 2), ('Corp', 2), ('연예', 2), ('라이프', 2), ('개인정보', 2), ('개인정보취급방침', 2), ('SK', 2), ('7위', 2), ('카페', 2), ('증권', 2), ('실시간', 2), ('공지사항', 2), ('개인', 2), ('2014', 2), ('오늘의', 2), ('6위', 2), ('게임', 2), ('FUN', 2), ('84', 2), ('쇼핑', 2), ('지도', 2), ('회사소개', 2), ('보호를', 2), ('웹툰', 2), ('뮤직', 2), ('12', 2), ('KT', 2), ('가', 2), ('1위', 2), ('4위', 2), ('오늘', 2), ('3위', 2), ('지역', 2), ('스포츠', 2), ('검색등록', 2), ('검색', 2), ('10', 2), ('서울', 2), ('nbsp', 2), ('광고', 2), ('전체', 2), ('9위', 2), ('3', 2), ('메일', 2), ('2위', 2), ('주세요', 2), ('다음', 2), ('필요합니다', 2), ('다운로드', 2), ('설정', 2), ('이용약관', 2), ('서비스', 2), ('바로', 2), ('펼치기', 2), ('사전', 2), ('더보기', 2), ('영화', 2), ('이슈', 2), ('동영상', 2), ('전체보기', 2), ('바로가기', 2), ('검색어', 2), ('1212사태', 2), ('약관', 2), ('10위', 2), ('금융', 2), ('및', 2), ('뉴스', 2), ('조현아', 2), ('블로그', 2), ('안내', 2), ('5위', 2), ('청소년보호정책', 2), ('11', 2), ('TV', 2), ('상승', 2), ('이전', 2), ('블랙프라이데이', 2), ('로그인', 2), ('오늘만', 1), ('수제돈까스', 1), ('한글캠페인', 1), ('위하여', 1), ('재료도', 1), ('나눔글꼴이', 1), ('나눔', 1), ('라이브', 1), ('옛날', 1), ('유지', 1), ('주말별식메뉴', 1), ('����', 1), ('신고', 1), ('2주', 1), ('나눔글꼴을', 1), ('선호주제설정', 1), ('������', 1), ('적극적', 1), ('볼', 1), ('��ȣ', 1), ('클릭하세요', 1), ('강아지', 1), ('잇다', 1), ('제대로', 1), ('주의', 1), ('관련', 1), ('배송혜택', 1), ('달라', 1), ('프로농구', 1), ('시스템글꼴', 1), ('행복한', 1), ('강추위', 1), ('none', 1), ('증시', 1), ('기존', 1), ('홈', 1), ('를', 1), ('6500만원을', 1), ('선수', 1), ('주제형캐스트', 1), ('때는', 1), ('켜기', 1), ('플랫폼', 1), ('檢', 1), ('제공되지', 1), ('즐거움', 1), ('두부로', 1), ('다음오픈캐스트', 1), ('영국', 1), ('주택', 1), ('체험학습', 1), ('영어사전', 1), ('맛도', 1), ('기사보기', 1), ('앱', 1), ('등', 1), ('통신', 1), ('네이버뉴스', 1), ('설치된', 1), ('�ٿ�ε�', 1), ('삭제한', 1), ('Kakao', 1), ('바버렛츠', 1), ('190', 1), ('저울질', 1), ('CJ몰', 1), ('인터넷을', 1), ('품은', 1), ('지켜주세요', 1), ('펜트하우스', 1), ('공만', 1), ('전문보기', 1), ('알티마', 1), ('서른살', 1), ('여배우', 1), ('따른', 1), ('KBL', 1), ('브라질', 1), ('보세요', 1), ('주요언론사', 1), ('002AN', 1), ('요리바람', 1), ('혜리', 1), ('첫구매', 1), ('5℃', 1), ('하프클럽', 1), ('흥덕구', 1), ('new', 1), ('전일대비', 1), ('528', 1), ('한끼', 1), ('한게임', 1), ('입력하신', 1), ('교황', 1), ('폰트를', 1), ('이유는', 1), ('켤', 1), ('전셋값', 1), ('맥커너히의', 1), ('N드라이브', 1), ('삼성', 1), ('����̺�', 1), ('만드는', 1), ('될까요', 1), ('의', 1), ('39', 1), ('맛있는', 1), ('확인', 1), ('입은', 1), ('하는', 1), ('30', 1), ('다운로드URL', 1), ('35', 1), ('주요', 1), ('0℃', 1), ('잡채3종셋트', 1), ('수사', 1), ('않고', 1), ('적립금추가로', 1), ('Daum', 1), ('내역이', 1), ('추천', 1), ('검색어저장', 1), ('구직자에', 1), ('고소한', 1), ('평화공세', 1), ('통일부', 1), ('��ް˻�', 1), ('2학년때', 1), ('다음앱', 1), ('내', 1), ('두부와', 1), ('타임스퀘어', 1), ('txt', 1), ('unit', 1), ('임의로', 1), ('질문', 1), ('인화물질', 1), ('김영광', 1), ('다음페이지', 1), ('고속도로교통상', 1), ('정책', 1), ('여왕', 1), ('광고안내', 1), ('6', 1), ('장모님', 1), ('술안주', 1), ('어묵잡채', 1), ('�α���', 1), ('대한', 1), ('입니다', 1), ('대구', 1), ('목록', 1), ('사망사고', 1), ('검색어를', 1), ('디앤샵', 1), ('담배요', 1), ('동계올림픽', 1), ('고양이인', 1), ('대해', 1), ('건강', 1), ('열기', 1), ('각선미', 1), ('나눔글꼴로', 1), ('두르고', 1), ('제휴문의', 1), ('네이버를', 1), ('든든한', 1), ('북스', 1), ('메뉴', 1), ('폰번호', 1), ('741', 1), ('아이디로', 1), ('Chrome', 1), ('저장되지', 1), ('집에서만들어먹는', 1), ('550', 1), ('호빗', 1), ('중기', 1), ('다음캐스트', 1), ('재밌는', 1), ('�˻�', 1), ('금', 1), ('3℃', 1), ('현대Hmall', 1), ('없어요', 1), ('품격이', 1), ('나만의', 1), ('7인회', 1), ('글꼴설정', 1), ('메탈', 1), ('quot', 1), ('AK몰', 1), ('아는', 1), ('���', 1), ('뜻', 1), ('연기돌', 1), ('����ϴ�', 1), ('인테리어', 1), ('���α׷�', 1), ('네이버캐스트', 1), ('공룡', 1), ('처벌', 1), ('제목', 1), ('아이디', 1), ('반드시', 1), ('1℃', 1), ('영자지', 1), ('사명', 1), ('기록', 1), ('백령도', 1), ('베일', 1), ('가능합니다', 1), ('인기기획전', 1), ('명품최대79', 1), ('라마', 1), ('지식iN', 1), ('안팔아요', 1), ('희비', 1), ('먹거리', 1), ('사랑의증거', 1), ('않은', 1), ('활성화로', 1), ('연합뉴스', 1), ('2호선', 1), ('추운날', 1), ('도움말보기', 1), ('정보', 1), ('말똥엄마', 1), ('부안상설시장', 1), ('라이센스', 1), ('사례', 1), ('12월', 1), ('스페셜', 1), ('맛본', 1), ('따뜻한', 1), ('계란초밥만들기', 1), ('검색어는', 1), ('제한', 1), ('무너졌다', 1), ('생각한대 ...

# %% [markdown]
# 새로 배운 부분 보다 기존의 것을 활용하는 부분이 더욱 어려웠다.

# %% [markdown]
# 파이썬이라는 새로운 언어를 배우면서 쉽고 강력하다고 느꼈다.
# 반면에 C와 Java에 익숙해져 있어서 그 것이 파이썬을 익히는데 방해가 되기도 했다.
